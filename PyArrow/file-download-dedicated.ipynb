# %% [markdown]
# # ML Model Example
#
# This example provides a simply query tutorial for InfluxDB Cloud Dedicated.

# %%
import influxdb_client_3 as InfluxDBClient3
from IPython.display import display, HTML
import pandas as pd
import numpy as np
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq

# %% [markdown]
# Next we provide our connection credentials to the InfluxDB 3.0 instance.
# `token` - scoped to the bucket you wish to query from.
# `host` - the host of your cloud dedicated instance.
# `client` - host wrapped in the flightclient class.

# %%
token = ''
host = 'b0c7cce5-8dbc-428e-98c6-7f996fb96467.a.influxdb.io'    
org = 'Jay-IOx'
db = 'factorydata'

client = InfluxDBClient3.InfluxDBClient3(token=token,
                         host=host,
                         org=org,
                         database=db)

# %%
query = "SELECT * FROM machine_data WHERE time >= now() - 30m"
table = client.query(query=query, language="influxql")
print(table)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 query = "SELECT * FROM machine_data WHERE time >= now() - 30m"
# ----> 2 table = client.query(query=query, language="influxql")
#       3 print(table)
#
# NameError: name 'client' is not defined

# %% [markdown]
# The `query_tools` function provides a wrapper to execution of a query agaisnt InfluxDB usinf flight. This function requires 3 paramters.
# `database`- this specifies the database you wish to direct your query at.
# `query` - This accepts a string literal of the query you wish to perform (SQL or InfluxQL).
# `query_type` - Whether this is a SQL or InfluxQL based query.

# %% [markdown]
# Return all columns from the table flight for the past 3 days.

# %%
df = table.to_pandas()
display(df)
# Out:
#        iox::measurement                          time          host  load
# 0          machine_data 2023-06-02 12:59:57.454138410  491cc20bbe13  50.0  \
# 1          machine_data 2023-06-02 12:59:57.457935726  491cc20bbe13  50.0
# 2          machine_data 2023-06-02 12:59:57.457953815  491cc20bbe13  50.0
# 3          machine_data 2023-06-02 12:59:58.454660523  491cc20bbe13  50.0
# 4          machine_data 2023-06-02 12:59:58.455401581  491cc20bbe13  50.0
# ...                 ...                           ...           ...   ...
# 336983     machine_data 2023-06-05 10:24:15.587576380  491cc20bbe13  50.0
# 336984     machine_data 2023-06-05 10:24:15.587984645  491cc20bbe13  50.0
# 336985     machine_data 2023-06-05 10:24:16.589058833  491cc20bbe13  50.0
# 336986     machine_data 2023-06-05 10:24:16.589635200  491cc20bbe13  50.0
# 336987     machine_data 2023-06-05 10:24:16.589998547  491cc20bbe13  50.0
#
#        machineID  power                      provider  temperature
# 0       machine1  202.0  Morales, Robinson and Newman         35.0  \
# 1       machine3  218.0                   Smith Group         35.0
# 2       machine2  217.0               Thomas and Sons         39.0
# 3       machine1  216.0  Morales, Robinson and Newman         35.0
# 4       machine3  212.0                   Smith Group         36.0
# ...          ...    ...                           ...          ...
# 336983  machine3  204.0                  Sandoval Ltd         40.0
# 336984  machine1  203.0                  Phillips PLC         36.0
# 336985  machine2  200.0     Lewis, Scott and Reynolds         37.0
# 336986  machine3  205.0                  Sandoval Ltd         36.0
# 336987  machine1  216.0                  Phillips PLC         40.0
#
#                    topic  vibration
# 0       machine/machine1       80.0
# 1       machine/machine3       83.0
# 2       machine/machine2       84.0
# 3       machine/machine1       89.0
# 4       machine/machine3       90.0
# ...                  ...        ...
# 336983  machine/machine3       88.0
# 336984  machine/machine1       80.0
# 336985  machine/machine2       81.0
# 336986  machine/machine3       87.0
# 336987  machine/machine1       82.0
#
# [336988 rows x 10 columns]

# %%
# Save the table to a Parquet file
pq.write_table(table, 'out.parquet' , version='2.6')

# %%
df.to_csv(index=False, 
path_or_buf='./out.csv')

# %%
result = df.to_json(orient="records", path_or_buf='./out.json', date_unit ='ns')

# %%
from pyarrow import orc
orc.write_table(table, 'out.orc')

# %%
from pyarrow import feather
feather.write_feather(table, 'out.feather')
